# %%
###FURNITURE
import cv2
import numpy as np
fur=cv2.imread(r'C:\Users\Amir\Desktop\New folder (3)\CODE PAYAN\Upper\UPPPer\codes\Distorting\UP\DATA BASE\DATA B\373.jpg')
# floor=np.copy(cropped)
# cv2.imshow('floor.png', floor)
# cv2.waitKey()
# cv2.destroyAllWindows()

#define new pixel
ptx=np.arange(0,350,1)
# print(ptx.shape)
pty=np.arange(0,240,1)
# print(pty.shape)
# print(ptx)
# print(pty)

#new x , y
x=(ptx.shape[0])
y=(pty.shape[0])
print(x,y)
reversed_pty = pty[::-1]
# print(ptx)
# print(reversed_pty)

#define Marix Base
datar=fur[:,:,2:3]/255
datag=fur[:,:,1:2]/255
datab=fur[:,:,0:1]/255
# r=np.zeros((y,x))
# g=np.zeros((y,x))
# b=np.zeros((y,x))
mat_fur = [[-1 for i in range(y)] for j in range(x)]
# print (r.shape)
# print (datar.shape)

# color detection
for i in range(x-1):
    for j in range(y-1):
        px=int((ptx[i]+ptx[i+1])/2)
        py=int((reversed_pty[j]+reversed_pty[j+1])/2)

        if (218/255<=datar[py][px]<=238/255) and (74/255<datag[py][px]<94/255) and (74/255<=datab[py][px]<=94/255):
            mat_fur[i][j]=0
            
        if (218/255<datar[py][px]<238/255) and (217/255<datag[py][px]<237/255) and (75/255<=datab[py][px]<=95/255):
            mat_fur[i][j]=1
            
        if (75/255<datar[py][px]<95/255) and (73/255<datag[py][px]<93/255) and (218/255<=datab[py][px]<=237/255):
            mat_fur[i][j]=2
            
        if (74/255<datar[py][px]<94/255) and (217/255<datag[py][px]<237/255) and (75/255<=datab[py][px]<=95/255):
            mat_fur[i][j]=3
            
        if (74/255<datar[py][px]<94/255) and (216/255<datag[py][px]<236/255) and (217/255<=datab[py][px]<=237/255):
            mat_fur[i][j]=4
            
        if (217/255<datar[py][px]<237/255) and (74/255<datag[py][px]<94/255) and (216/255<=datab[py][px]<=236/255):
            mat_fur[i][j]=5
            
        if (181/255<datar[py][px]<201/255) and (109/255<datag[py][px]<129/255) and (110/255<=datab[py][px]<=130/255):
            mat_fur[i][j]=6
            
        if (216/255<datar[py][px]<236/255) and (146/255<datag[py][px]<166/255) and (74/255<=datab[py][px]<=94/255):
            mat_fur[i][j]=7
            
        if (110/255<datar[py][px]<130/255) and (182/255<datag[py][px]<202/255) and (181/255<=datab[py][px]<=201/255):
            mat_fur[i][j]=8
            
        if (74/255<datar[py][px]<94/255) and (146/255<datag[py][px]<166/255) and (73/255<=datab[py][px]<=93/255):
            mat_fur[i][j]=9
n_units = len(mat4d)
print(n_units) 

# amir=0

# for i in range(x-1):
#     for j in range(y-1):
#         px=int((ptx[i]+ptx[i+1])/2)
#         py=int((reversed_pty[j]+reversed_pty[j+1])/2)
#         if mat_fur[i][j]==0:
#             amir+=1
#             cv2.circle(fur, (px,py), 3, (0,0,250), 1)
# cv2.imwrite(r'C:\Users\Amir\Desktop\a7.jpg',fur)
# print(amir)       
        
        
        


###BLUE ZERO
bed_blue_x=[[None for i in range(1)] for j in range(n_units)]
bed_blue_y=[[None for i in range(1)] for j in range(n_units)]

for i in range(len(bed_blue_x)):
    bed_blue_x[i].pop(0)
for i in range(len(bed_blue_y)):
    bed_blue_y[i].pop(0)
bed_blue_x

for z in range(n_units):
    for i in range(sx):
        for j in range(sy):
            if mat4d[z][FN-1][i][j]==z:
                if mat3d[FN-1][i][j]==0:
#                     points.append(rg.Point3d(i,j,0))
                    bed_blue_x[z].append(i)
                    bed_blue_y[z].append(j)
# print(bed_blue_x)       
# print(bed_blue_y)
bed_blue_fur=[[None for i in range(2)] for j in range(n_units)]
bed_blue_bp=[[None for i in range(2)] for j in range(n_units)]
bed_blue_size=[[0 for i in range(4)] for j in range(n_units)]
# for i in range(len(bed_blue_fur)):
#     bed_blue_fur[i].pop(0)
# for i in range(len(bed_red_size)):
#     bed_red_size[i].pop(0)
# for i in range(len(bed_blue_bp)):
#     bed_blue_bp[i].pop(0)
    
bed_blue_size=np.array(bed_blue_size)


for z in range(n_units):
    if len(bed_blue_x[z])>1:
        for k in range((bed_blue_x[z][0]*10)-5,(bed_blue_x[z][-1]*10)+5):
            for l in range((bed_blue_y[z][0]*10)-5,(bed_blue_y[z][-1]*10)+5):
#                print l
                if mat_fur[k][l]==0:
                    bed_blue_size[z][0]+=1
                if mat_fur[k][l]==1:
                    bed_blue_size[z][1]+=1
                if mat_fur[k][l]==2:
                    bed_blue_size[z][2]+=1
                if mat_fur[k][l]==3:
                    bed_blue_size[z][3]+=1
# print (bed_blue_size)
for z in range(n_units):
    if len(bed_blue_x[z])>1:
        if bed_blue_size[z][0]!=0:
            if 300<(bed_blue_size[z][0])<420:
                bed_blue_fur[z][0]=('BR0')
            elif 200<=(bed_blue_size[z][0])<260:
                bed_blue_fur[z][0]=('BR1')
            elif 115<=(bed_blue_size[z][0])<170:
                bed_blue_fur[z][1]=('BR2')
        if bed_blue_size[z][1]!=0:
            if 300<(bed_blue_size[z][1])<420:
                bed_blue_fur[z][0]=('BY0')
            elif 200<=(bed_blue_size[z][1])<260:
                bed_blue_fur[z][0]=('BY1')
            elif 115<=(bed_blue_size[z][1])<170:
                bed_blue_fur[z][1]=('BY2')
        if bed_blue_size[z][2]!=0:
            if 300<(bed_blue_size[z][2])<420:
                bed_blue_fur[z][0]=('BB0')
            elif 200<=(bed_blue_size[z][2])<260:
                bed_blue_fur[z][0]=('BB1')
            elif 115<=(bed_blue_size[z][2])<170:
                bed_blue_fur[z][1]=('BB2')
        if bed_blue_size[z][3]!=0:
            if 300<(bed_blue_size[z][3])<420:
                bed_blue_fur[z][0]=('BG0')
            elif 200<=(bed_blue_size[z][3])<260:
                bed_blue_fur[z][0]=('BG1')
            elif 115<=(bed_blue_size[z][3])<170:
                bed_blue_fur[z][1]=('BG2')
                
for z in range(n_units):
    if len(bed_blue_x[z])>1:
        for k in range((bed_blue_x[z][0]*10)-5,(bed_blue_x[z][-1]*10)+5):
            for l in range((bed_blue_y[z][0]*10)-5,(bed_blue_y[z][-1]*10)+5):
                    if mat_fur[k][l]==0:
                        if bed_blue_size[z][0]>170:
                            if mat_fur[k-1][l]!=0 and mat_fur[k][l-1]!=0:
                                bed_blue_bp[z][0]=(k/10,l/10,0)
                        if bed_blue_size[z][0]<170:
                            if mat_fur[k-1][l]!=0 and mat_fur[k][l+1]!=0:
                                bed_blue_bp[z][1]=(k/10,l/10,0)
                           
                    elif mat_fur[k][l]==1:
                        if bed_blue_size[z][1]>170:
                            if mat_fur[k][l+1]!=1 and mat_fur[k-1][l]!=1:
                                bed_blue_bp[z][0]=(k/10,l/10,0)
                        if bed_blue_size[z][1]<170:
                            if mat_fur[k+1][l]!=1 and mat_fur[k][l-1]!=1:
                                bed_blue_bp[z][1]=(k/10,l/10,0)
                
                    elif mat_fur[k][l]==2:
                        if bed_blue_size[z][2]>170:
                            if mat_fur[k+1][l]!=2 and mat_fur[k][l+1]!=2:
                                bed_blue_bp[z][0]=(k/10,l/10,0)
                        if bed_blue_size[z][2]<170:
                            if mat_fur[k-1][l]!=2 and mat_fur[k][l-1]!=2:
                                bed_blue_bp[z][1]=(k/10,l/10,0)
                           
                    elif mat_fur[k][l]==3:
                        if bed_blue_size[z][3]>170:
                            if mat_fur[k-1][l]!=3 and mat_fur[k][l-1]!=3:
                                bed_blue_bp[z][0]=(k/10,l/10,0)
                        if bed_blue_size[z][3]<170:
                            if mat_fur[k+1][l]!=3 and mat_fur[k][l-1]!=3:
                                bed_blue_bp[z][1]=(k/10,l/10,0)

# print (len(bed_blue_size[5]))
print(bed_blue_fur)
print(bed_blue_bp)

##RED ONE
bed_red_x=[[None for i in range(1)] for j in range(n_units)]
bed_red_y=[[None for i in range(1)] for j in range(n_units)]

for i in range(len(bed_red_x)):
    bed_red_x[i].pop(0)
for i in range(len(bed_red_y)):
    bed_red_y[i].pop(0)
bed_red_x

for z in range(n_units):
    for i in range(sx):
        for j in range(sy):
            if mat4d[z][FN-1][i][j]==z:
                if mat3d[FN-1][i][j]==1:
#                     points.append(rg.Point3d(i,j,0))
                    bed_red_x[z].append(i)
                    bed_red_y[z].append(j)
# print(bed_red_x)       
# print(bed_red_y)
bed_red_fur=[[None for i in range(2)] for j in range(n_units)]
bed_red_bp=[[None for i in range(2)] for j in range(n_units)]
bed_red_size=[[0 for i in range(4)] for j in range(n_units)]
# for i in range(len(bed_red_fur)):
#     bed_red_fur[i].pop(0)
# for i in range(len(bed_red_size)):
#     bed_red_size[i].pop(0)
# for i in range(len(bed_red_bp)):
#     bed_red_bp[i].pop(0)
    
bed_red_size=np.array(bed_red_size)


for z in range(n_units):
    if len(bed_red_x[z])>1:
        for k in range((bed_red_x[z][0]*10)-5,(bed_red_x[z][-1]*10)+5):
            for l in range((bed_red_y[z][0]*10)-5,(bed_red_y[z][-1]*10)+5):
#                print l
                if mat_fur[k][l]==0:
                    bed_red_size[z][0]+=1
                if mat_fur[k][l]==1:
                    bed_red_size[z][1]+=1
                if mat_fur[k][l]==2:
                    bed_red_size[z][2]+=1
                if mat_fur[k][l]==3:
                    bed_red_size[z][3]+=1
bed_red_size
for z in range(n_units):
    if len(bed_red_x[z])>1:
        if bed_red_size[z][0]!=0:
            if 300<(bed_red_size[z][0])<420:
                bed_red_fur[z][0]=('BR0')
            elif 200<=(bed_red_size[z][0])<260:
                bed_red_fur[z][0]=('BR1')
            elif 120<=(bed_red_size[z][0])<170:
                bed_red_fur[z][1]=('BR2')
        if bed_red_size[z][1]!=0:
            if 300<(bed_red_size[z][1])<420:
                bed_red_fur[z][0]=('BY0')
            elif 200<=(bed_red_size[z][1])<260:
                bed_red_fur[z][0]=('BY1')
            elif 115<=(bed_red_size[z][1])<170:
                bed_red_fur[z][1]=('BY2')
        if bed_red_size[z][2]!=0:
            if 300<(bed_red_size[z][2])<420:
                bed_red_fur[z][0]=('BB0')
            elif 200<=(bed_red_size[z][2])<260:
                bed_red_fur[z][0]=('BB1')
            elif 115<=(bed_red_size[z][2])<170:
                bed_red_fur[z][1]=('BB2')
        if bed_red_size[z][3]!=0:
            if 300<(bed_red_size[z][3])<420:
                bed_red_fur[z][0]=('BG0')
            elif 200<=(bed_red_size[z][3])<260:
                bed_red_fur[z][0]=('BG1')
            elif 115<=(bed_red_size[z][3])<170:
                bed_red_fur[z][1]=('BG2')
                
for z in range(n_units):
    if len(bed_red_x[z])>1:
         for k in range((bed_red_x[z][0]*10)-5,(bed_red_x[z][-1]*10)+5):
            for l in range((bed_red_y[z][0]*10)-5,(bed_red_y[z][-1]*10)+5):
                    if mat_fur[k][l]==0:
                        if bed_red_size[z][0]>170:
                            if mat_fur[k-1][l]!=0 and mat_fur[k][l-1]!=0:
                                bed_red_bp[z][0]=(k/10,l/10,0)
                        if bed_red_size[z][0]<170:
                            if mat_fur[k-1][l]!=0 and mat_fur[k][l+1]!=0:
                                bed_red_bp[z][1]=(k/10,l/10,0)
                           
                    elif mat_fur[k][l]==1:
                        if bed_red_size[z][1]>170:
                            if mat_fur[k][l+1]!=1 and mat_fur[k-1][l]!=1:
                                bed_red_bp[z][0]=(k/10,l/10,0)
                        if bed_red_size[z][1]<170:
                            if mat_fur[k+1][l]!=1 and mat_fur[k][l-1]!=1:
                                bed_red_bp[z][1]=(k/10,l/10,0)
                
                    elif mat_fur[k][l]==2:
                        if bed_red_size[z][2]>170:
                            if mat_fur[k+1][l]!=2 and mat_fur[k][l+1]!=2:
                                bed_red_bp[z][0]=(k/10,l/10,0)
                        if bed_red_size[z][2]<170:
                            if mat_fur[k-1][l]!=2 and mat_fur[k][l-1]!=2:
                                bed_red_bp[z][1]=(k/10,l/10,0)
                           
                    elif mat_fur[k][l]==3:
                        if bed_red_size[z][3]>170:
                            if mat_fur[k-1][l]!=3 and mat_fur[k][l-1]!=3:
                                bed_red_bp[z][0]=(k/10,l/10,0)
                        if bed_red_size[z][3]<170:
                            if mat_fur[k+1][l]!=3 and mat_fur[k][l-1]!=3:
                                bed_red_bp[z][1]=(k/10,l/10,0)
# print (len(bed_red_size[1]))
# print (bed_red_size)
print(bed_red_fur)
print(bed_red_bp)


###Orange two
bed_orange_x=[[None for i in range(1)] for j in range(n_units)]
bed_orange_y=[[None for i in range(1)] for j in range(n_units)]

for i in range(len(bed_orange_x)):
    bed_orange_x[i].pop(0)
for i in range(len(bed_orange_y)):
    bed_orange_y[i].pop(0)
bed_orange_x

for z in range(n_units):
    for i in range(sx):
        for j in range(sy):
            if mat4d[z][FN-1][i][j]==z:
                if mat3d[FN-1][i][j]==2:
#                     points.append(rg.Point3d(i,j,0))
                    bed_orange_x[z].append(i)
                    bed_orange_y[z].append(j)
# print(bed_orange_x)       
# print(bed_orange_y)
bed_orange_fur=[[None for i in range(2)] for j in range(n_units)]
bed_orange_bp=[[None for i in range(2)] for j in range(n_units)]
bed_orange_size=[[0 for i in range(4)] for j in range(n_units)]
# for i in range(len(bed_orange_fur)):
#     bed_orange_fur[i].pop(0)
# for i in range(len(bed_red_size)):
#     bed_red_size[i].pop(0)
# for i in range(len(bed_orange_bp)):
#     bed_orange_bp[i].pop(0)
    
bed_orange_size=np.array(bed_orange_size)


for z in range(n_units):
    if len(bed_orange_x[z])>1:
         for k in range((bed_orange_x[z][0]*10)-5,(bed_orange_x[z][-1]*10)+5):
            for l in range((bed_orange_y[z][0]*10)-5,(bed_orange_y[z][-1]*10)+5):
#                print l
                if mat_fur[k][l]==0:
                    bed_orange_size[z][0]+=1
                if mat_fur[k][l]==1:
                    bed_orange_size[z][1]+=1
                if mat_fur[k][l]==2:
                    bed_orange_size[z][2]+=1
                if mat_fur[k][l]==3:
                    bed_orange_size[z][3]+=1
bed_orange_size
for z in range(n_units):
    if len(bed_orange_x[z])>1:
        if bed_orange_size[z][0]!=0:
            if 22<(bed_orange_size[z][0])<40:
                bed_orange_fur[z][0]=('WR0')
            elif 4<(bed_orange_size[z][0])<18:
                bed_orange_fur[z][1]=('WR1')
            
        if bed_orange_size[z][1]!=0:
            if 22<(bed_orange_size[z][1])<40:
                bed_orange_fur[z][0]=('WY0')
            elif 4<(bed_orange_size[z][1])<18:
                bed_orange_fur[z][1]=('WY1')

        if bed_orange_size[z][2]!=0:
            if 22<(bed_orange_size[z][2])<40:
                bed_orange_fur[z][0]=('WB0')
            elif 4<(bed_orange_size[z][2])<18:
                bed_orange_fur[z][1]=('WB1')

        if bed_orange_size[z][3]!=0:
            if 22<(bed_orange_size[z][3])<40:
                bed_orange_fur[z][0]=('WG0')
            elif 4<(bed_orange_size[z][3])<18:
                bed_orange_fur[z][1]=('WG1')

                
for z in range(n_units):
    if len(bed_orange_x[z])>1:
        for k in range((bed_orange_x[z][0]*10)-8,(bed_orange_x[z][-1]*10)+8):
            for l in range((bed_orange_y[z][0]*10)-8,(bed_orange_y[z][-1]*10)+8):
                if mat_fur[k][l]==0:
                    if bed_orange_size[z][0]>22:
                        if mat_fur[k-1][l]!=0 and mat_fur[k][l-1]!=0:
                            bed_orange_bp[z][0]=(k/10,l/10,0)
                    elif bed_orange_size[z][0]<18:
                        if mat_fur[k-1][l]!=0 and mat_fur[k][l-1]!=0:
                            bed_orange_bp[z][1]=(k/10,l/10,0)
                           
                if mat_fur[k][l]==1:
                    if bed_orange_size[z][1]>22:
                        if mat_fur[k-1][l]!=1 and mat_fur[k][l-1]!=1:
                            bed_orange_bp[z][0]=(k/10,l/10,0)
                    elif bed_orange_size[z][1]<18:
                        if mat_fur[k-1][l]!=1 and mat_fur[k][l-1]!=1:
                            bed_orange_bp[z][1]=(k/10,l/10,0)
                
                if mat_fur[k][l]==2:
                    if bed_orange_size[z][2]>22:
                        if mat_fur[k-1][l]!=2 and mat_fur[k][l-1]!=2:
                            bed_orange_bp[z][0]=(k/10,l/10,0)
                    elif bed_orange_size[z][2]<18:
                        if mat_fur[k-1][l]!=2 and mat_fur[k][l-1]!=2:
                            bed_orange_bp[z][1]=(k/10,l/10,0)
                           
                if mat_fur[k][l]==3:
                    if bed_orange_size[z][3]>22:
                        if mat_fur[k-1][l]!=3 and mat_fur[k][l-1]!=3:
                            bed_orange_bp[z][0]=(k/10,l/10,0)
                    elif bed_orange_size[z][3]<18:
                        if mat_fur[k-1][l]!=3 and mat_fur[k][l-1]!=3:
                            bed_orange_bp[z][1]=(k/10,l/10,0)

print (bed_orange_size)
print(bed_orange_fur)
print(bed_orange_bp)

###Blue-Red three
bed_bluered_x=[[None for i in range(1)] for j in range(n_units)]
bed_bluered_y=[[None for i in range(1)] for j in range(n_units)]

for i in range(len(bed_bluered_x)):
    bed_bluered_x[i].pop(0)
for i in range(len(bed_bluered_y)):
    bed_bluered_y[i].pop(0)
bed_bluered_x

for z in range(n_units):
    for i in range(sx):
        for j in range(sy):
            if mat4d[z][FN-1][i][j]==z:
                if mat3d[FN-1][i][j]==3:
#                     points.append(rg.Point3d(i,j,0))
                    bed_bluered_x[z].append(i)
                    bed_bluered_y[z].append(j)
print(bed_bluered_x)       
print(bed_bluered_y)
bed_bluered_fur=[[None for i in range(2)] for j in range(n_units)]
bed_bluered_bp=[[None for i in range(2)] for j in range(n_units)]
bed_bluered_size=[[0 for i in range(4)] for j in range(n_units)]
# for i in range(len(bed_bluered_fur)):
#     bed_bluered_fur[i].pop(0)
# for i in range(len(bed_red_size)):
#     bed_red_size[i].pop(0)
# for i in range(len(bed_bluered_bp)):
#     bed_bluered_bp[i].pop(0)
    
bed_bluered_size=np.array(bed_bluered_size)


for z in range(n_units):
    if len(bed_bluered_x[z])>1:
        for k in range((bed_bluered_x[z][0]*10)-8,(bed_bluered_x[z][-1]*10)+8):
            for l in range((bed_bluered_y[z][0]*10)-8,(bed_bluered_y[z][-1]*10)+8):
#                print l
                if mat_fur[k][l]==0:
                    bed_bluered_size[z][0]+=1
                if mat_fur[k][l]==1:
                    bed_bluered_size[z][1]+=1
                if mat_fur[k][l]==2:
                    bed_bluered_size[z][2]+=1
                if mat_fur[k][l]==3:
                    bed_bluered_size[z][3]+=1
print (bed_bluered_size)
for z in range(n_units):
    if len(bed_bluered_x[z])>1:
        if bed_bluered_size[z][0]!=0:
            if 80<(bed_bluered_size[z][0])<115:
                bed_bluered_fur[z][0]='TR0'
            elif 2<(bed_bluered_size[z][0])<60:
                bed_bluered_fur[z][1]='TR1'
            
        if bed_bluered_size[z][1]!=0:
            if 80<(bed_bluered_size[z][1])<115:
                bed_bluered_fur[z][0]='TY0'
            elif 15<(bed_bluered_size[z][1])<60:
                bed_bluered_fur[z][1]='TY1'
            
        if bed_bluered_size[z][2]!=0:
            if 80<(bed_bluered_size[z][2])<115:
                bed_bluered_fur[z][0]='TB0'
            elif 15<(bed_bluered_size[z][2])<60:
                bed_bluered_fur[z][1]='TB1'
          
        if bed_bluered_size[z][3]!=0:
            if 80<(bed_bluered_size[z][3])<115:
                bed_bluered_fur[z][0]='TG0'
            elif 15<(bed_bluered_size[z][3])<60:
                bed_bluered_fur[z][1]='TG1'
                
for z in range(n_units):
    if len(bed_bluered_x[z])>1:
        for k in range((bed_bluered_x[z][0]*10)-8,(bed_bluered_x[z][-1]*10)+8):
            for l in range((bed_bluered_y[z][0]*10)-8,(bed_bluered_y[z][-1]*10)+8):
                if mat_fur[k][l]==0:
                    if bed_bluered_size[z][0]>80:
                        if mat_fur[k-1][l]!=0 and mat_fur[k][l-1]!=0:
                            bed_bluered_bp[z][0]=((k/10,l/10,0))
                    elif bed_bluered_size[z][0]<60:
                        if mat_fur[k-1][l]!=0 and mat_fur[k][l-1]!=0:
                            bed_bluered_bp[z][1]=((k/10,l/10,0))

                if mat_fur[k][l]==1:
                    if bed_bluered_size[z][1]>80:
                        if mat_fur[k][l+1]!=1 and mat_fur[k-1][l]!=1:
                            bed_bluered_bp[z][0]=((k/10,l/10,0))
                    elif bed_bluered_size[z][1]<60:
                        if mat_fur[k][l+1]!=1 and mat_fur[k-1][l]!=1:
                            bed_bluered_bp[z][1]=((k/10,l/10,0))

                if mat_fur[k][l]==2:
                    if bed_bluered_size[z][2]>80:
                        if mat_fur[k+1][l]!=2 and mat_fur[k][l+1]!=2:
                            bed_bluered_bp[z][0]=((k/10,l/10,0))
                    elif bed_bluered_size[z][2]<60:
                        if mat_fur[k+1][l]!=2 and mat_fur[k][l+1]!=2:
                            bed_bluered_bp[z][1]=((k/10,l/10,0))
                            
                if mat_fur[k][l]==3:
                    if bed_bluered_size[z][3]>80:
                        if mat_fur[k-1][l]!=3 and mat_fur[k][l-1]!=3:
                            bed_bluered_bp[z][0]=((k/10,l/10,0))
                    elif bed_bluered_size[z][3]<60:
                        if mat_fur[k-1][l]!=3 and mat_fur[k][l-1]!=3:
                            bed_bluered_bp[z][1]=((k/10,l/10,0))

# print (bed_bluered_size)
print(bed_bluered_fur)
print(bed_bluered_bp)

# ####Yellow Four
# bed_yellow_x=[[None for i in range(1)] for j in range(n_units)]
# bed_yellow_y=[[None for i in range(1)] for j in range(n_units)]

# for i in range(len(bed_yellow_x)):
#     bed_yellow_x[i].pop(0)
# for i in range(len(bed_yellow_y)):
#     bed_yellow_y[i].pop(0)
# bed_yellow_x

# for z in range(n_units):
#     for i in range(sx):
#         for j in range(sy):
#             if mat4d[z][FN-1][i][j]==z:
#                 if mat3d[FN-1][i][j]==4:
# #                     points.append(rg.Point3d(i,j,0))
#                     bed_yellow_x[z].append(i)
#                     bed_yellow_y[z].append(j)
# # print(bed_yellow_x)       
# # print(bed_yellow_y)

# bed_yellow_bp=[[[0 for i in range(4)]for k in range(4)] for j in range(n_units)]

# for z in range(n_units):
#     if len(bed_yellow_x[z])>1:
#         for k in range((bed_yellow_x[z][0]*10)-8,(bed_yellow_x[z][-1]*10)+8):
#             for l in range((bed_yellow_y[z][0]*10)-8,(bed_yellow_y[z][-1]*10)+8):
#                 if mat_fur[k][l]==0:
#                     if mat_fur[k-1][l]!=0 and mat_fur[k][l-1]!=0:
#                         bed_yellow_bp[z][0][0]=((k/10,l/10,0))
#                     if mat_fur[k+1][l]!=0 and mat_fur[k][l-1]!=0:
#                         bed_yellow_bp[z][0][1]=((k/10,l/10,0))
#                     if mat_fur[k+1][l]!=0 and mat_fur[k][l+1]!=0:
#                         bed_yellow_bp[z][0][2]=((k/10,l/10,0))
#                     if mat_fur[k-1][l]!=0 and mat_fur[k][l+1]!=0:
#                         bed_yellow_bp[z][0][3]=((k/10,l/10,0))

#                 if mat_fur[k][l]==1:
#                     if mat_fur[k-1][l]!=1 and mat_fur[k][l-1]!=1:
#                         bed_yellow_bp[z][1][0]=((k/10,l/10,0))
#                     if mat_fur[k+1][l]!=1 and mat_fur[k][l-1]!=1:
#                         bed_yellow_bp[z][1][1]=((k/10,l/10,0))
#                     if mat_fur[k+1][l]!=1 and mat_fur[k][l+1]!=1:
#                         bed_yellow_bp[z][1][2]=((k/10,l/10,0))
#                     if mat_fur[k-1][l]!=1 and mat_fur[k][l+1]!=1:
#                         bed_yellow_bp[z][1][3]=((k/10,l/10,0))

#                 if mat_fur[k][l]==2:
#                     if mat_fur[k-1][l]!=2 and mat_fur[k][l-1]!=2:
#                         bed_yellow_bp[z][2][0]=((k/10,l/10,0))
#                     if mat_fur[k+1][l]!=2 and mat_fur[k][l-1]!=2:
#                         bed_yellow_bp[z][2][1]=((k/10,l/10,0))
#                     if mat_fur[k+1][l]!=2 and mat_fur[k][l+1]!=2:
#                         bed_yellow_bp[z][2][2]=((k/10,l/10,0))
#                     if mat_fur[k-1][l]!=2 and mat_fur[k][l+1]!=2:
#                         bed_yellow_bp[z][2][3]=((k/10,l/10,0))

#                 if mat_fur[k][l]==3:
#                     if mat_fur[k-1][l]!=3 and mat_fur[k][l-1]!=3:
#                         bed_yellow_bp[z][3][0]=((k/10,l/10,0))
#                     if mat_fur[k+1][l]!=3 and mat_fur[k][l-1]!=3:
#                         bed_yellow_bp[z][3][1]=((k/10,l/10,0))
#                     if mat_fur[k+1][l]!=3 and mat_fur[k][l+1]!=3:
#                         bed_yellow_bp[z][3][2]=((k/10,l/10,0))
#                     if mat_fur[k-1][l]!=3 and mat_fur[k][l+1]!=3:
#                         bed_yellow_bp[z][3][3]=((k/10,l/10,0))


# # print(bed_yellow_bp)

####Purpule five
bed_purpule_x=[[None for i in range(1)] for j in range(n_units)]
bed_purpule_y=[[None for i in range(1)] for j in range(n_units)]

for i in range(len(bed_purpule_x)):
    bed_purpule_x[i].pop(0)
for i in range(len(bed_purpule_y)):
    bed_purpule_y[i].pop(0)
bed_purpule_x

for z in range(n_units):
    for i in range(sx):
        for j in range(sy):
            if mat4d[z][FN-1][i][j]==z:
                if mat3d[FN-1][i][j]==5:
#                     points.append(rg.Point3d(i,j,0))
                    bed_purpule_x[z].append(i)
                    bed_purpule_y[z].append(j)
for i in range(n_units):
    bed_purpule_x[i]=list(set(bed_purpule_x[i]))
for i in range(n_units):
    bed_purpule_x[i]=sorted(bed_purpule_x[i])
for i in range(n_units):
    bed_purpule_y[i]=list(set(bed_purpule_y[i]))
for i in range(n_units):
    bed_purpule_y[i]=sorted(bed_purpule_y[i])
print(bed_purpule_x)       
print(bed_purpule_y)
bed_purpule_fur=[[None for i in range(1)] for j in range(n_units)]
bed_purpule_bp=[[None for i in range(1)] for j in range(n_units)]
bed_purpule_size=[[0 for i in range(4)] for j in range(n_units)]
for i in range(len(bed_purpule_fur)):
    bed_purpule_fur[i].pop(0)
# for i in range(len(bed_red_size)):
#     bed_red_size[i].pop(0)
for i in range(len(bed_purpule_bp)):
    bed_purpule_bp[i].pop(0)
    
bed_purpule_size=np.array(bed_purpule_size)


for z in range(n_units):
    if len(bed_purpule_x[z])>1:
        for k in range((bed_purpule_x[z][0]*10)-5,(bed_purpule_x[z][-1]*10)+5):
            for l in range((bed_purpule_y[z][0]*10)-5,(bed_purpule_y[z][-1]*10)+5):
#                print l
                if mat_fur[k][l]==6:
                    bed_purpule_size[z][0]+=1
                if mat_fur[k][l]==7:
                    bed_purpule_size[z][1]+=1
                if mat_fur[k][l]==8:
                    bed_purpule_size[z][2]+=1
                if mat_fur[k][l]==9:
                    bed_purpule_size[z][3]+=1
bed_purpule_size
for z in range(n_units):
    if len(bed_purpule_x[z])>1:
        if bed_purpule_size[z][0]!=0:
            if 1800<(bed_purpule_size[z][0])<2200:
                bed_purpule_fur[z].append('LR0')
            elif 880<(bed_purpule_size[z][0])<1110:
                bed_purpule_fur[z].append('LR1')
            
        if bed_purpule_size[z][1]!=0:
            if 1800<(bed_purpule_size[z][1])<2200:
                bed_purpule_fur[z].append('LY0')
            elif 880<(bed_purpule_size[z][1])<1110:
                bed_purpule_fur[z].append('LY1')
            
        if bed_purpule_size[z][2]!=0:
            if 1800<(bed_purpule_size[z][2])<2200:
                bed_purpule_fur[z].append('LB0')
            elif 880<(bed_purpule_size[z][2])<1110:
                bed_purpule_fur[z].append('LB1')
          
        if bed_purpule_size[z][3]!=0:
            if 1800<(bed_purpule_size[z][3])<2200:
                bed_purpule_fur[z].append('LG0')
            elif 880<(bed_purpule_size[z][3])<1110:
                bed_purpule_fur[z].append('LG1')

                
s=[[0 for i in range(1)] for j in range(n_units)]
s=np.array(s)
for z in range(n_units):
    if len(bed_purpule_x[z])>1:
        for k in range((bed_purpule_x[z][0]*10)-5,(bed_purpule_x[z][-1]*10)+5):
            for l in range((bed_purpule_y[z][0]*10)-5,(bed_purpule_y[z][-1]*10)+5):
                if mat_fur[k][l]==6:
                    if mat_fur[k-1][l]!=6 and mat_fur[k][l+1]!=6:
                        bed_purpule_bp[z].append((k/10,l/10,0))

                if mat_fur[k][l]==7:
                    if mat_fur[k+1][l]!=7 and mat_fur[k][l-1]!=7:
                        bed_purpule_bp[z].append((k/10,l/10,0))
#                     elif mat_fur[k+1][l]!=1 and mat_fur[k][l+1]!=1:
#                         bed_bluered_bp[z][1]=(k/10,l/10,0)

                if mat_fur[k][l]==8:
                    if mat_fur[k-1][l]!=8 and mat_fur[k][l-1]!=8:
#                         print ("true")
                        bed_purpule_bp[z].append((k/10,l/10,0))

                if mat_fur[k][l]==9:
                    if mat_fur[k+1][l]!=9 and mat_fur[k][l-1]!=9:
                        bed_purpule_bp[z].append((k/10,l/10,0))
                
                if mat_fur[k][l]==4:
                    if mat_fur[k-1][l]!=4 and mat_fur[k][l-1]!=4:
                        bed_purpule_fur[z].append('LL2')
                        bed_purpule_bp[z].append((k/10,l/10,0))
                if mat_fur[k][l]==5:
                    s[z]+=1
                    
# print (s)
s_p_x=[[0 for i in range(1)] for j in range(n_units)]
s=np.array(s)
s_p_y=[[0 for i in range(1)] for j in range(n_units)]
for z in range(n_units):
    if len(bed_purpule_x[z])>1:
        for k in range((bed_purpule_x[z][0]*10)-5,(bed_purpule_x[z][-1]*10)+5):
            for l in range((bed_purpule_y[z][0]*10)-5,(bed_purpule_y[z][-1]*10)+5):                        
                if mat_fur[k][l]==5:
                    s_p_x[z].append(k)
                    s_p_y[z].append(l)
# print ((s_p_x[1][-1])-s_p_x[1][0])
# print ((s_p_y[1][-1])-s_p_y[1][0])
for z in range(n_units):
    if len(bed_purpule_x[z])>1:
        for k in range((bed_purpule_x[z][0]*10)-5,(bed_purpule_x[z][-1]*10)+5):
            for l in range((bed_purpule_y[z][0]*10)-5,(bed_purpule_y[z][-1]*10)+5):                        
                if mat_fur[k][l]==5:
    
                    if mat_fur[k-1][l]!=5 and mat_fur[k][l-1]!=5:
                        if 140<s[z]<180:
                            if (s_p_x[z][-1])-(s_p_x[z][0])>(s_p_y[z][-1])-(s_p_y[z][0]):
                                bed_purpule_fur[z].append('LP300')
                            else:
                                bed_purpule_fur[z].append('LP301')
                                
                            bed_purpule_bp[z].append((k/10,l/10,0))
                        elif 195<s[z]<300:
#                             if_p_x[z][-1])-(s_p_x[z][0])>(s_p_y[z][-1])-(s_p_y[z][0]):
                            bed_purpule_fur[z].append('LP310')
#                             else:
#                                 bed_purpule_fur[z].append('LP311')
                                
                            bed_purpule_bp[z].append((k/10,l/10,0))
                        elif 480<s[z]<524:
                            if (s_p_x[z][-1])-(s_p_x[z][0])>(s_p_y[z][-1])-(s_p_y[z][0]):
                                bed_purpule_fur[z].append('LP320')
                            else:
                                bed_purpule_fur[z].append('LP321')
                                
                            bed_purpule_bp[z].append((k/10,l/10,0))
                        elif 750<s[z]<860:
                            if (s_p_x[z][-1])-(s_p_x[z][0])>(s_p_y[z][-1])-(s_p_y[z][0]):
                                bed_purpule_fur[z].append('LP330')
                            else:
                                bed_purpule_fur[z].append('LP331')
                            bed_purpule_bp[z].append((k/10,l/10,0))
                        elif 1100<s[z]<1500:
                            if (s_p_x[z][-1])-(s_p_x[z][0])>(s_p_y[z][-1])-(s_p_y[z][0]):
                                bed_purpule_fur[z].append('LP340')
                            else:
                                bed_purpule_fur[z].append('LP341')
                            bed_purpule_bp[z].append((k/10,l/10,0))
                        
                        
                        
# print (bed_purpule_size)
print(bed_purpule_fur)
print(bed_purpule_bp)

# # # ####Blue light Six


# ####Green eight
bed_green_x=[[None for i in range(1)] for j in range(n_units)]
bed_green_y=[[None for i in range(1)] for j in range(n_units)]

for i in range(len(bed_green_x)):
    bed_green_x[i].pop(0)
for i in range(len(bed_green_y)):
    bed_green_y[i].pop(0)
bed_green_x

for z in range(n_units):
    for i in range(sx):
        for j in range(sy):
            if mat4d[z][FN-1][i][j]==z:
                if mat3d[FN-1][i][j]==8:
#                     points.append(rg.Point3d(i,j,0))
                    bed_green_x[z].append(i)
                    bed_green_y[z].append(j)
# print(bed_green_x)       
# print(bed_green_y)
bed_green_fur=[[None for i in range(1)] for j in range(n_units)]
bed_green_bp=[[None for i in range(1)] for j in range(n_units)]
bed_green_size=[[0 for i in range(4)] for j in range(n_units)]
for i in range(len(bed_green_fur)):
    bed_green_fur[i].pop(0)
# for i in range(len(bed_red_size)):
#     bed_red_size[i].pop(0)
for i in range(len(bed_green_bp)):
    bed_green_bp[i].pop(0)
    
bed_green_size=np.array(bed_green_size)

# print(bed_green_x)
# print(bed_green_y)
for z in range(n_units):
    if len(bed_green_x[z])>1:
        for k in range((bed_green_x[z][0]*10)-10,(bed_green_x[z][-1]*10)+10):
            for l in range((bed_green_y[z][0]*10)-10,(bed_green_y[z][-1]*10)+10):
#                print l
                if mat_fur[k][l]==0:
                    bed_green_size[z][0]+=1
                if mat_fur[k][l]==1:
                    bed_green_size[z][1]+=1
                if mat_fur[k][l]==2:
                    bed_green_size[z][2]+=1
                if mat_fur[k][l]==3:
                    bed_green_size[z][3]+=1
# # bed_green_size
for z in range(n_units):
    if len(bed_green_x[z])>1:
        if bed_green_size[z][0]!=0:
            if 850<(bed_green_size[z][0])<1100:
                bed_green_fur[z].append('SR0')
            elif 520<(bed_green_size[z][0])<720:
                bed_green_fur[z].append('SR1')
            
        if bed_green_size[z][1]!=0:
            if 850<(bed_green_size[z][1])<1100:
                bed_green_fur[z].append('SY0')
            elif 520<(bed_green_size[z][1])<720:
                bed_green_fur[z].append('SY1')
            
        if bed_green_size[z][2]!=0:
            if 850<(bed_green_size[z][2])<1100:
                bed_green_fur[z].append('SB0')
            elif 520<(bed_green_size[z][2])<720:
                bed_green_fur[z].append('SB1')
           
        if bed_green_size[z][3]!=0:
            if 850<(bed_green_size[z][3])<1100:
                bed_green_fur[z].append('SG0')
            elif 520<(bed_green_size[z][3])<720:
                bed_green_fur[z].append('SG1')
           
                
for z in range(n_units):
    if len(bed_green_x[z])>1:
        for k in range((bed_green_x[z][0]*10)-5,(bed_green_x[z][-1]*10)+5):
            for l in range((bed_green_y[z][0]*10)-5,(bed_green_y[z][-1]*10)+5):
                if mat_fur[k][l]==0:
                    if mat_fur[k-1][l]!=0 and mat_fur[k][l-1]!=0:
                        bed_green_bp[z].append((k/10,l/10,0))

                if mat_fur[k][l]==1:
                    if mat_fur[k][l+1]!=1 and mat_fur[k-1][l]!=1:
                        bed_green_bp[z].append((k/10,l/10,0))


                if mat_fur[k][l]==2:
                    if mat_fur[k+1][l]!=2 and mat_fur[k][l+1]!=2:
                        bed_green_bp[z].append((k/10,l/10,0))

                if mat_fur[k][l]==3:
                    if mat_fur[k-1][l]!=3 and mat_fur[k][l-1]!=3:
                        bed_green_bp[z].append((k/10,l/10,0))
print (bed_green_size)
print(bed_green_fur)
print(bed_green_bp)

####Brown nine
bed_brown_x=[[None for i in range(1)] for j in range(n_units)]
bed_brown_y=[[None for i in range(1)] for j in range(n_units)]

for i in range(len(bed_brown_x)):
    bed_brown_x[i].pop(0)
for i in range(len(bed_brown_y)):
    bed_brown_y[i].pop(0)
bed_brown_x

for z in range(n_units):
    for i in range(sx):
        for j in range(sy):
            if mat4d[z][FN-1][i][j]==z:
                if mat3d[FN-1][i][j]==9:
#                     points.append(rg.Point3d(i,j,0))
                    bed_brown_x[z].append(i)
                    bed_brown_y[z].append(j)
# print(bed_brown_x)       
# print(bed_brown_y)
bed_brown_fur=[[None for i in range(2)] for j in range(n_units)]
bed_brown_bp=[[None for i in range(2)] for j in range(n_units)]
bed_brown_size=[[0 for i in range(4)] for j in range(n_units)]
# for i in range(len(bed_brown_fur)):
#     bed_brown_fur[i].pop(0)
# for i in range(len(bed_red_size)):
#     bed_red_size[i].pop(0)
# for i in range(len(bed_brown_bp)):
#     bed_brown_bp[i].pop(0)
    
bed_brown_size=np.array(bed_brown_size)

print(bed_brown_x)
print(bed_brown_y)
for z in range(n_units):
    if len(bed_brown_x[z])>1:
        for k in range((bed_brown_x[z][0]*10)-5,(bed_brown_x[z][-1]*10)+5):
            for l in range((bed_brown_y[z][0]*10)-5,(bed_brown_y[z][-1]*10)+5):
#                print l
                if mat_fur[k][l]==0:
                    bed_brown_size[z][0]+=1
                if mat_fur[k][l]==1:
                    bed_brown_size[z][1]+=1
                if mat_fur[k][l]==2:
                    bed_brown_size[z][2]+=1
                if mat_fur[k][l]==3:
                    bed_brown_size[z][3]+=1
# bed_brown_size
for z in range(n_units):
    if len(bed_brown_x[z])>1:
        if bed_brown_size[z][0]!=0:
            if 300<(bed_brown_size[z][0])<420:
                bed_brown_fur[z][0]=('BR0')
            elif 200<=(bed_brown_size[z][0])<260:
                bed_brown_fur[z][0]=('BR1')
            elif 115<=(bed_brown_size[z][0])<170:
                bed_brown_fur[z][1]=('BR2')
        if bed_brown_size[z][1]!=0:
            if 300<(bed_brown_size[z][1])<420:
                bed_brown_fur[z][0]=('BY0')
            elif 200<=(bed_brown_size[z][1])<260:
                bed_brown_fur[z][0]=('BY1')
            elif 115<=(bed_brown_size[z][1])<170:
                bed_brown_fur[z][1]=('BY2')
        if bed_brown_size[z][2]!=0:
            if 300<(bed_brown_size[z][2])<420:
                bed_brown_fur[z][0]=('BB0')
            elif 200<=(bed_brown_size[z][2])<260:
                bed_brown_fur[z][0]=('BB1')
            elif 115<=(bed_brown_size[z][2])<170:
                bed_brown_fur[z][1]=('BB2')
        if bed_brown_size[z][3]!=0:
            if 300<(bed_brown_size[z][3])<420:
                bed_brown_fur[z][0]=('BG0')
            elif 200<=(bed_brown_size[z][3])<260:
                bed_brown_fur[z][0]=('BG1')
            elif 115<=(bed_brown_size[z][3])<170:
                bed_brown_fur[z][1]=('BG2')
                
for z in range(n_units):
    if len(bed_brown_x[z])>1:
        for k in range((bed_brown_x[z][0]*10)-5,(bed_brown_x[z][-1]*10)+5):
            for l in range((bed_brown_y[z][0]*10)-5,(bed_brown_y[z][-1]*10)+5):
                if mat_fur[k][l]==0:
                    if bed_brown_size[z][0]>170:
                        if mat_fur[k-1][l]!=0 and mat_fur[k][l-1]!=0:
                            bed_brown_bp[z][0]=(k/10,l/10,0)
                    if bed_brown_size[z][0]<170:
                        if mat_fur[k-1][l]!=0 and mat_fur[k][l+1]!=0:
                            bed_brown_bp[z][1]=(k/10,l/10,0)
                           
                elif mat_fur[k][l]==1:
                    if bed_brown_size[z][1]>170:
                        if mat_fur[k][l+1]!=1 and mat_fur[k-1][l]!=1:
                            bed_brown_bp[z][0]=(k/10,l/10,0)
                    if bed_brown_size[z][1]<170:
                        if mat_fur[k+1][l]!=1 and mat_fur[k][l-1]!=1:
                            bed_brown_bp[z][1]=(k/10,l/10,0)
                
                elif mat_fur[k][l]==2:
                    if bed_brown_size[z][2]>170:
                        if mat_fur[k+1][l]!=2 and mat_fur[k][l+1]!=2:
                            bed_brown_bp[z][0]=(k/10,l/10,0)
                    if bed_brown_size[z][2]<170:
                        if mat_fur[k-1][l]!=2 and mat_fur[k][l-1]!=2:
                            bed_brown_bp[z][1]=(k/10,l/10,0)
                           
                elif mat_fur[k][l]==3:
                    if bed_brown_size[z][3]>170:
                        if mat_fur[k-1][l]!=3 and mat_fur[k][l-1]!=3:
                            bed_brown_bp[z][0]=(k/10,l/10,0)
                    if bed_brown_size[z][3]<170:
                        if mat_fur[k+1][l]!=3 and mat_fur[k][l-1]!=3:
                            bed_brown_bp[z][1]=(k/10,l/10,0)
# print (len(bed_red_size[1]))
# print (bed_brown_size)
# print(bed_brown_fur)
# print(bed_brown_bp)

mat_fur=[[None for i in range(1)] for j in range(7)]
mat_bp=[[None for i in range(1)] for j in range(7)]
for i in range(len(mat_fur)):
    mat_fur[i].pop(0)
# (bed_blue_fur)
# (bed_blue_bp)
mat_fur[0]=bed_blue_fur
mat_bp[0]=bed_blue_bp
#
# (bed_red_fur)
# (bed_red_bp)
mat_fur[1]=bed_red_fur
mat_bp[1]=bed_red_bp
#
# (bed_orange_fur)
# (bed_orange_bp)
mat_fur[2]=bed_orange_fur
mat_bp[2]=bed_orange_bp
#
# (bed_bluered_fur)
# (bed_bluered_bp)
mat_fur[3]=bed_bluered_fur
mat_bp[3]=bed_bluered_bp
#
# bed_yellow_bp
#
# (bed_purpule_fur)
# (bed_purpule_bp)
mat_fur[4]=bed_purpule_fur
mat_bp[4]=bed_purpule_bp
#
# (bed_green_fur)
# (bed_green_bp)
mat_fur[5]=bed_green_fur
mat_bp[5]=bed_green_bp
#
# (bed_brown_fur)
# (bed_brown_bp)
mat_fur[6]=bed_brown_fur
mat_bp[6]=bed_brown_bp
# mat_fur=np.array(mat_fur)
# mat_fur.shape
# mat_bp=np.array(mat_bp)
###################################Furniture Matrices
# bed_yellow_bp
# print (mat_fur[4])
# print (mat_bp[4])
# print (bed_purpule_size)
